# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
vol_df = pd.read_csv("volc_data.csv")
quake_df = pd.read_csv("quake_data.csv")

# %%
new_vol = vol_df["Year"]
new_volc = vol_df["Month"]
new_vol2 = vol_df["Latitude"]
new_vol3 = vol_df["Longitude"]

# %%
new_quakeY = quake_df["YEAR"]
new_quakeM = quake_df["MONTH"]
new_quakeL = quake_df["LATITUDE"]
new_quakeLO = quake_df["LONGITUDE"]

# %%
new_quakeLO = new_quakeLO.dropna(axis=0,how='any')
new_quakeL = new_quakeL.dropna(axis=0,how='any')

# %%
new_quakeLO = pd.to_numeric(new_quakeLO, downcast='float', errors='coerce')
new_quakeL = pd.to_numeric(new_quakeL, downcast='float', errors='coerce')

# %%
print(len(new_quakeY))
print(len(new_quakeM))
print(len(new_quakeL))
print(len(new_quakeLO))
# Out:
# 6045
# 6045
# 5996
# 5996

# %%
vol_df.head()
# Out:
#      Year  Month  Day  TSU   EQ             Name            Location  \
# 0     NaN    NaN  NaN  NaN  NaN              NaN                 NaN
# 1 -4360.0    NaN  NaN  NaN  NaN  Macauley Island         Kermadec Is
# 2 -4350.0    NaN  NaN  NaN  NaN            Kikai           Ryukyu Is
# 3 -4050.0    NaN  NaN  NaN  NaN           Masaya           Nicaragua
# 4 -4000.0    NaN  NaN  NaN  NaN             Pago  New Britain-SW Pac
#
#             Country  Latitude  Longitude                 ...                  \
# 0               NaN       NaN        NaN                 ...
# 1       New Zealand   -30.200   -178.470                 ...
# 2             Japan    30.780    130.280                 ...
# 3         Nicaragua    11.984    -86.161                 ...
# 4  Papua New Guinea    -5.580    150.520                 ...
#
#    TOTAL_DEATHS TOTAL_DEATHS_DESCRIPTION TOTAL_MISSING  \
# 0           NaN                      NaN           NaN
# ...

# %%
quake_df.head()
# Out:
#     I_D FLAG_TSUNAMI  YEAR  MONTH  DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  \
# 0     1          NaN -2150    NaN  NaN   NaN     NaN                 NaN
# 1     3          NaN -2000    NaN  NaN   NaN     NaN    NaN         18.0
# 2     2          Tsu -2000    NaN  NaN   NaN     NaN    NaN          NaN
# 3  5877          Tsu -1610    NaN  NaN   NaN     NaN    NaN          NaN
# 4     8          NaN -1566    NaN  NaN   NaN     NaN                 NaN
#
#    EQ_PRIMARY               ...                 TOTAL_MISSING  \
# 0         7.3               ...                           NaN
# 1         7.1               ...                           NaN
# 2         NaN               ...                           NaN
# 3         NaN               ...                           NaN
# 4         NaN               ...                           NaN
#
#    TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  TOTAL_INJURIES_DESCRIPTION  \
# 0                        NaN             NaN                         NaN
# ...

# %%
lat = quake_df["LATITUDE"]
long = quake_df["LONGITUDE"]

# %%
lati = vol_df["Latitude"]
longi = vol_df["Longitude"]

# %%
print(long.head())#earthquake
print(longi.head())#volcano
# Out:
# 0    35.5
# 1    58.2
# 2    35.8
# 3    25.4
# 4    35.3
# Name: LONGITUDE, dtype: object
# 0        NaN
# 1   -178.470
# 2    130.280
# 3    -86.161
# 4    150.520
# Name: Longitude, dtype: float64

# %%
new_vol = vol_df.dropna(axis=0, how="any")
new_vol.head()
# Out:
# Empty DataFrame
# Columns: [Year, Month, Day, TSU, EQ, Name, Location, Country, Latitude, Longitude, Elevation, Type, Status, Time, VEI, Agent, DEATHS, DEATHS_DESCRIPTION, MISSING, MISSING_DESCRIPTION, INJURIES, INJURIES_DESCRIPTION, DAMAGE_MILLIONS_DOLLARS, DAMAGE_DESCRIPTION, HOUSES_DESTROYED, HOUSES_DESTROYED_DESCRIPTION, TOTAL_DEATHS, TOTAL_DEATHS_DESCRIPTION, TOTAL_MISSING, TOTAL_MISSING_DESCRIPTION, TOTAL_INJURIES, TOTAL_INJURIES_DESCRIPTION, TOTAL_DAMAGE_MILLIONS_DOLLARS, TOTAL_DAMAGE_DESCRIPTION, TOTAL_HOUSES_DESTROYED, TOTAL_HOUSES_DESTROYED_DESCRIPTION]
# Index: []
#
# [0 rows x 36 columns]

# %%
new_quake = quake_df.dropna(axis=0, how="any")
new_quake.head()
# Out:
# Empty DataFrame
# Columns: [I_D, FLAG_TSUNAMI, YEAR, MONTH, DAY, HOUR, MINUTE, SECOND, FOCAL_DEPTH, EQ_PRIMARY, EQ_MAG_MW, EQ_MAG_MS, EQ_MAG_MB, EQ_MAG_ML, EQ_MAG_MFA, EQ_MAG_UNK, INTENSITY, COUNTRY, STATE, LOCATION_NAME, LATITUDE, LONGITUDE, REGION_CODE, DEATHS, DEATHS_DESCRIPTION, MISSING, MISSING_DESCRIPTION, INJURIES, INJURIES_DESCRIPTION, DAMAGE_MILLIONS_DOLLARS, DAMAGE_DESCRIPTION, HOUSES_DESTROYED, HOUSES_DESTROYED_DESCRIPTION, HOUSES_DAMAGED, HOUSES_DAMAGED_DESCRIPTION, TOTAL_DEATHS, TOTAL_DEATHS_DESCRIPTION, TOTAL_MISSING, TOTAL_MISSING_DESCRIPTION, TOTAL_INJURIES, TOTAL_INJURIES_DESCRIPTION, TOTAL_DAMAGE_MILLIONS_DOLLARS, TOTAL_DAMAGE_DESCRIPTION, TOTAL_HOUSES_DESTROYED, TOTAL_HOUSES_DESTROYED_DESCRIPTION, TOTAL_HOUSES_DAMAGED, TOTAL_HOUSES_DAMAGED_DESCRIPTION]
# Index: []
#
# [0 rows x 47 columns]

# %%
image = plt.imread("earth.jpg")# volcanoes
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])
plt.scatter(longi,lati, color = "white")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.xlim(-179.984,180)
plt.ylim(-62.877,73.122)
plt.show()

# %%
image = plt.imread("Pacific-ocean-blank-map.jpg")# volcanoes
fig, ax = plt.subplots()
ax.imshow(image , extent = [-180,180,-90,90])
plt.scatter(longi,lati, color = "purple")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.xlim(-179.984,180)
plt.ylim(-62.877,73.122)
plt.show()

# %%
quake_df.head()
# Out:
#     I_D FLAG_TSUNAMI  YEAR  MONTH  DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  \
# 0     1          NaN -2150    NaN  NaN   NaN     NaN                 NaN
# 1     3          NaN -2000    NaN  NaN   NaN     NaN    NaN         18.0
# 2     2          Tsu -2000    NaN  NaN   NaN     NaN    NaN          NaN
# 3  5877          Tsu -1610    NaN  NaN   NaN     NaN    NaN          NaN
# 4     8          NaN -1566    NaN  NaN   NaN     NaN                 NaN
#
#    EQ_PRIMARY               ...                 TOTAL_MISSING  \
# 0         7.3               ...                           NaN
# 1         7.1               ...                           NaN
# 2         NaN               ...                           NaN
# 3         NaN               ...                           NaN
# 4         NaN               ...                           NaN
#
#    TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  TOTAL_INJURIES_DESCRIPTION  \
# 0                        NaN             NaN                         NaN
# ...

# %%
image = plt.imread("earth.jpg") #earthquake
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])
plt.scatter(new_quakeLO,new_quakeL, color = "white")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.xlim(-179.984,180)
plt.ylim(-62.877,73.122)
plt.show()

# %%
image = plt.imread("Pacific-ocean-blank-map.jpg") #earthquake
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])
plt.scatter(new_quakeLO,new_quakeL, color = "yellow")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.xlim(-179.984,180)
plt.ylim(-62.877,73.122)
plt.show()

# %%
df_volc = pd.read_csv("volcano - Sheet1.csv")
df_earth = pd.read_csv("1900 earthquakes - Sheet1.csv")

# %%
df_volc.head()
# Out:
#      Year  Month   Day  TSU   EQ        Name           Location  \
# 0     NaN    NaN   NaN  NaN  NaN         NaN                NaN
# 1  1800.0    6.0  24.0  NaN  NaN   San Jorge             Azores
# 2  1800.0   10.0   8.0  NaN  NaN      Guntur               Java
# 3  1800.0   10.0  30.0  NaN  NaN       Mayon  Luzon-Philippines
# 4  1800.0    NaN   NaN  NaN  NaN  St. Helens      US-Washington
#
#          Country  Latitude  Longitude                 ...                  \
# 0            NaN       NaN        NaN                 ...
# 1       Portugal    38.650    -28.080                 ...
# 2      Indonesia    -7.130    107.830                 ...
# 3    Philippines    13.257    123.685                 ...
# 4  United States    46.200   -122.180                 ...
#
#    TOTAL_DEATHS TOTAL_DEATHS_DESCRIPTION TOTAL_MISSING  \
# 0           NaN                      NaN           NaN
# 1           9.0                      1.0           NaN
# ...

# %%
df_earth.head()
# Out:
#     I_D FLAG_TSUNAMI  YEAR  MONTH   DAY  HOUR  MINUTE  SECOND  FOCAL_DEPTH  \
# 0  9925          Tsu  1900    1.0  10.0   NaN     NaN     NaN          NaN
# 1  2566          NaN  1900    1.0  11.0   9.0     7.0     NaN          NaN
# 2  2567          NaN  1900    1.0  14.0   NaN     NaN     NaN          NaN
# 3  2569          NaN  1900    1.0  20.0   6.0    33.0    30.0         10.0
# 4  2571          NaN  1900    5.0  16.0  20.0    12.0     NaN         60.0
#
#    EQ_PRIMARY               ...                 TOTAL_MISSING  \
# 0         NaN               ...                           NaN
# 1         7.8               ...                           NaN
# 2         NaN               ...                           NaN
# 3         7.4               ...                           NaN
# 4         7.8               ...                           NaN
#
#    TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  TOTAL_INJURIES_DESCRIPTION  \
# ...

# %%
v_long = df_volc["Longitude"]
v_lat = df_volc["Latitude"]
e_long = df_earth["LONGITUDE"]
e_lat = df_earth["LATITUDE"]

# %%
image = plt.imread("earth.jpg") #volcanoes 1800
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])
plt.scatter(v_long, v_lat, color = "orange", s = 20)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.xlim(-179.984,180)
plt.ylim(-62.877,73.122)
plt.show()

# %%
image = plt.imread("earth.jpg") #earthquake 1900
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])
plt.scatter(e_long, e_lat, color = "pink", s = 6)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.xlim(-179.984,180)
plt.ylim(-62.877,73.122)
plt.show()

# %%
len(df_earth)
# Out:
# 3585

# %%
len(quake_df)
# Out:
# 6045

# %%
len(df_volc)
# Out:
# 608

# %%
len(vol_df)
# Out:
# 820

# %%
# here we index all the data since 2000 for volcanoes
new_volca = vol_df  
new_volca = vol_df.loc[new_volca["Year"] >= 2000]
fire_long = new_volca["Longitude"].loc[new_volca["Year"] >= 2000]
fire_lat = new_volca["Latitude"].loc[new_volca["Year"] >= 2000]
fire_vei = new_volca["VEI"].loc[new_volca["Year"] >= 2000]

# %%
# here we index all the data since 2000 for earthquakes
new_quake = quake_df
new_quake = quake_df.loc[new_quake["YEAR"]>= 2000]
earth_long = new_quake["LONGITUDE"].loc[new_quake["YEAR"]>= 2000]
earth_lat = new_quake["LATITUDE"].loc[new_quake["YEAR"]>= 2000]
earth_eq = new_quake["EQ_PRIMARY"].loc[new_quake["YEAR"]>= 2000]

# %%
len(fire_long)
# Out:
# 104

# %%
len(earth_long)
# Out:
# 1054

# %%
new_quake.head()
# Out:
#        I_D FLAG_TSUNAMI  YEAR  MONTH   DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  \
# 4991  5551          NaN  2000    1.0   3.0  22.0    34.0   12.6         33.0
# 4992  5552          NaN  2000    1.0  11.0  23.0    43.0   56.4         10.0
# 4993  5553          NaN  2000    1.0  14.0  23.0    37.0    7.8         33.0
# 4994  5554          NaN  2000    2.0   2.0  22.0    58.0    1.5         33.0
# 4995  5555          NaN  2000    2.0   7.0  19.0    34.0     57          5.0
#
#       EQ_PRIMARY               ...                 TOTAL_MISSING  \
# 4991         4.6               ...                           NaN
# 4992         5.1               ...                           NaN
# 4993         5.9               ...                           NaN
# 4994         5.3               ...                           NaN
# 4995         4.5               ...                           NaN
#
#       TOTAL_MISSING_DESCRIPTION  TOTAL_INJURIES  TOTAL_INJURIES_DESCRIPTION  \
# ...

# %%
len(fire_lat)
# Out:
# 104

# %%
new_volca.head()
# Out:
#        Year  Month   Day  TSU   EQ         Name      Location        Country  \
# 716  2000.0    6.0  27.0  TSU   EQ  Miyake-jima  Izu Is-Japan          Japan
# 717  2000.0    7.0  27.0  NaN  NaN       Semeru          Java      Indonesia
# 718  2000.0    8.0  23.0  NaN  NaN       Arenal    Costa Rica     Costa Rica
# 719  2000.0   11.0   3.0  NaN  NaN      Kilauea   Hawaiian Is  United States
# 720  2000.0   11.0   NaN  NaN  NaN       Merapi          Java      Indonesia
#
#      Latitude  Longitude                 ...                  TOTAL_DEATHS  \
# 716    34.080    139.530                 ...                           1.0
# 717    -8.108    112.920                 ...                           2.0
# 718    10.463    -84.703                 ...                           2.0
# 719    19.425   -155.292                 ...                           2.0
# 720    -7.542    110.442                 ...                           1.0
#
# ...

# %%
# only earthquakes since 2000

# %%
def colorGroup(col, number):
    c_min = col.min()
    c_max = col.max()
    interval = (c_max-c_min)/number
    interval_list = []
    cur_num = c_min
    while len(interval_list)<number:
        cur_num+=interval
        interval_list.append(cur_num)
    return interval_list


print(colorGroup(new_quake["YEAR"], 5))
# Out:
# [2003.5999999999999, 2007.1999999999998, 2010.7999999999997, 2014.3999999999996, 2017.9999999999995]

# %%
def listofcolors(column):                       # chnages color every 3 years 
    year_list = colorGroup(column,5)            # starting from 2003
    color = []
    for year in column:
        if year <= year_list[0]:
            color.append([255/255,255/255,255/255]) # white
        elif year <= year_list[1]:
            color.append([216/255,62/255,205/224]) # purple
        elif year <= year_list[2]:
            color.append([25/255,138/255,198/255]) # blue
        elif year <= year_list[3]:
            color.append([246/255,255/255,0/255]) # yellow
        elif year <= year_list[4]:
            color.append([224/255,22/255,59/255]) # red
        else:
            color.append([142/255,138/255,122/255]) # grey 
    return color

# %%
magnitude2 = new_quake["YEAR"]

# %%
colorList = listofcolors(new_quake["YEAR"])
print(len(colorList))
# Out:
# 1054

# %%
image = plt.imread("earth.jpg") #earthquakes 2000
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])
plt.scatter(earth_long, earth_lat, c = colorList, s = 20)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.xlim(-179.984,180)
plt.ylim(-62.877,73.122)
plt.show()

# %%
def sizeFunc(column, numSize):    #earthquakes 2000
        empty_list = []
        interval = (column.max()- column.min())/numSize
        num_temp = column.min()
        while len(empty_list) < numSize:
            num_temp += interval
            empty_list.append(num_temp)
        return empty_list


sizeFunc(quake_df["EQ_PRIMARY"], 6)
mage = quake_df["EQ_PRIMARY"]



def Func(column):
    empty_list = sizeFunc(vol_df["VEI"], 6) # size represents intensity 
    sizes = []                               # shape represents either volcano or earthquake
    for item in column:                      # color represents the year
        if item <= empty_list[0]:
            sizes.append(7)
        elif item <= empty_list[1]:
            sizes.append(30)
        elif item <= empty_list[2]:
             sizes.append(70)
        elif item <= empty_list[3]:
            sizes.append(100)
        elif item <= empty_list[4]:
            sizes.append(200)
        elif item <= empty_list[5]:
            sizes.append(300)    
    return sizes

s = Func(mag)

image = plt.imread("earth.jpg")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])
plt.scatter(earth_long, earth_lat, color = colorList, s = s, marker = "*" )
plt.xlim(-180, 180)
plt.title("Earthquakes since 2000")
plt.savefig("earthquake_map", dpi = 1000)

# %%
# only volcanoes since 2000

# %%
def colorGroup(col, number): #volcanoes
    c_min = col.min()
    c_max = col.max()
    interval = (c_max-c_min)/number
    interval_list = []
    cur_num = c_min
    while len(interval_list)<number:
        cur_num+=interval
        interval_list.append(cur_num)
    return interval_list

print(colorGroup(new_volca["Year"], 5))
# Out:
# [2003.5999999999999, 2007.1999999999998, 2010.7999999999997, 2014.3999999999996, 2017.9999999999995]

# %%
def listofcolors(column):                       # chnages color every 3 years 
    year_list = colorGroup(column,5)            # starting from 2003
    color = []
    for year in column:
        if year <= year_list[0]:
            color.append([255/255,255/255,255/255]) # white
        elif year <= year_list[1]:
            color.append([216/255,62/255,205/224]) # purple
        elif year <= year_list[2]:
            color.append([25/255,138/255,198/255]) # blue
        elif year <= year_list[3]:
            color.append([246/255,255/255,0/255]) # yellow
        elif year <= year_list[4]:
            color.append([224/255,22/255,59/255]) # red
        else:
            color.append([142/255,138/255,122/255]) # grey 
    return color

# %%
magnitude = new_volca["Year"]

# %%
colorList = listofcolors(new_volca["Year"])
print(len(colorList))
# Out:
# 104

# %%
image = plt.imread("earth.jpg") #volcanoes 2000
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])
plt.scatter(fire_long, fire_lat, color = colorList, s = 20)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.xlim(-179.984,180)
plt.ylim(-62.877,73.122)
plt.show()

# %%
def sizeFunc(column, numSize):
        empty_list = []
        interval = (column.max()- column.min())/numSize
        num_temp = column.min()
        while len(empty_list) < numSize:
            num_temp += interval
            empty_list.append(num_temp)
        return empty_list

sizeFunc(vol_df["VEI"], 6)
mag = vol_df["VEI"]



def Func(column):
    empty_list = sizeFunc(vol_df["VEI"], 6) # size represents intensity 
    sizes = []                               # shape represents either volcano or earthquake
    for item in column:                      # color represents the year
        if item <= empty_list[0]:
            sizes.append(7)
        elif item <= empty_list[1]:
            sizes.append(30)
        elif item <= empty_list[2]:
             sizes.append(70)
        elif item <= empty_list[3]:
            sizes.append(100)
        elif item <= empty_list[4]:
            sizes.append(200)
        elif item <= empty_list[5]:
            sizes.append(300)
        
    return sizes

s = Func(mag)

image = plt.imread("earth.jpg")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])
plt.scatter(fire_long, fire_lat, c = colorList, s = s, marker = "^" )
plt.xlim(-180, 180)
plt.title("Volcanoes since 2000")
plt.savefig("volcano_graph",dpi = 1000)

# %%
#combined

# %%
# we created this function to split the data into 5 intervals 
def colorGroup(col, number):
    c_min = col.min()
    c_max = col.max()
    interval = (c_max-c_min)/number
    interval_list = []
    cur_num = c_min
    while len(interval_list)<number:
        cur_num+=interval
        interval_list.append(cur_num)
    return interval_list


print(colorGroup(new_quake["YEAR"], 5))
print(colorGroup(new_volca["Year"], 5))
# Out:
# [2003.5999999999999, 2007.1999999999998, 2010.7999999999997, 2014.3999999999996, 2017.9999999999995]
# [2003.5999999999999, 2007.1999999999998, 2010.7999999999997, 2014.3999999999996, 2017.9999999999995]

# %%
# chnages color every 3 years starting from 2000
def listofcolors(column):                        
    year_list = colorGroup(column,5)            
    color = []
    for year in column:
        if year <= year_list[0]:
            color.append([255/255,255/255,255/255]) # white
        elif year <= year_list[1]:
            color.append([216/255,62/255,205/224]) # purple
        elif year <= year_list[2]:
            color.append([25/255,138/255,198/255]) # blue
        elif year <= year_list[3]:
            color.append([246/255,255/255,0/255]) # yellow
        elif year <= year_list[4]:
            color.append([224/255,22/255,59/255]) # red
        else:
            color.append([142/255,138/255,122/255]) # grey 
    return color

# %%
magnitude = new_quake["YEAR"]
magnitude = new_volca["Year"]

# %%
colorList = listofcolors(new_quake["YEAR"])
print(len(colorList))
colorList = listofcolors(new_volca["Year"])
print(len(colorList))
# Out:
# 1054
# 104

# %%
image = plt.imread("earth.jpg") #earthquakes 2000
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])
plt.scatter(fire_long, fire_lat, color = colorList, s = 20)
plt.scatter(earth_long, earth_lat, c = colorList, s = 20)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.xlim(-179.984,180)
plt.ylim(-62.877,73.122)
#plt.savefig("Earthquakes",dpi = 1000)
plt.show()

# %%
#this function is used to create marker sizes 
def sizeFunc(column, numSize):    
        empty_list = []
        interval = (column.max()- column.min())/numSize
        num_temp = column.min()
        while len(empty_list) < numSize:
            num_temp += interval
            empty_list.append(num_temp)
        return empty_list
sizeFunc(quake_df["EQ_PRIMARY"], 6)
mage = quake_df["EQ_PRIMARY"]
sizeFunc(vol_df["VEI"], 6)
mag = vol_df["VEI"]


# this assignes the size of the marker from the range that we made
def Func(column):
    empty_list = sizeFunc(vol_df["VEI"], 6) 
    sizes = []                               
    for item in column:                      
        if item <= empty_list[0]:
            sizes.append(7)
        elif item <= empty_list[1]:
            sizes.append(30)
        elif item <= empty_list[2]:
             sizes.append(70)
        elif item <= empty_list[3]:
            sizes.append(100)
        elif item <= empty_list[4]:
            sizes.append(200)
        elif item <= empty_list[5]:
            sizes.append(300)
    return sizes
s = Func(mag)

# this code is where everything comes together in the same map 
image = plt.imread("earth.jpg")
fig, ax = plt.subplots()
ax.imshow(image, extent = [-180,180,-90,90])
plt.scatter(earth_long, earth_lat, color = colorList, s = s, marker = "*")
plt.scatter(fire_long, fire_lat, color = colorList, s = s, marker = "^" )
plt.xlim(-180, 180)
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.title("Volcanoes and Earthquakes since 2000")
plt.savefig("volcanoes_and_Earthquakes.png",dpi = 1000)
