# %%
from plotly.offline import init_notebook_mode, iplot
from IPython.display import display, HTML
import pandas as pd

# %%
dataset= pd.read_csv("quake_data.csv")

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
years = ['1800','1820','1840','1860','1880','1900','1910','1920','1930','1940','1950','1960','1970','1980','1990','2000','2005','2010','2015','2018']

# %%
countries=[]
country=pd.unique(dataset["COUNTRY"])
for country in country:
    if country is not countries:
        countries.append(country)
print(countries)
# Out:
# ['JORDAN', 'TURKMENISTAN', 'SYRIA', 'GREECE', 'ISRAEL', 'ITALY', 'LEBANON', 'IRAN', 'INDIA', 'TURKEY', 'KYRGYZSTAN', 'EGYPT', 'SPAIN', 'PORTUGAL', 'CHINA', 'RUSSIA', 'ALBANIA', 'BULGARIA', 'GEORGIA', 'CYPRUS', 'PAKISTAN', 'SOUTH KOREA', 'AFGHANISTAN', 'MACEDONIA', 'TUNISIA', 'AZERBAIJAN', 'THAILAND', 'FRANCE', 'KAZAKHSTAN', 'NORTH KOREA', 'SLOVENIA', 'IRAQ', 'JAPAN', 'ARMENIA', 'UK', 'UZBEKISTAN', 'ALGERIA', 'ICELAND', 'SWITZERLAND', 'YEMEN', 'NEPAL', 'MOROCCO', 'CROATIA', 'UKRAINE', 'AUSTRIA', 'BOSNIA-HERZEGOVINA', 'SLOVAKIA', 'SERBIA', 'PERU', 'IRELAND', 'VENEZUELA', 'USA', 'DOMINICAN REPUBLIC', 'GERMANY', 'ROMANIA', 'CHILE', 'MEXICO', 'HONDURAS', 'AZORES (PORTUGAL)', 'ECUADOR', 'MONTENEGRO', 'GUATEMALA', 'COLOMBIA', 'EL SALVADOR', 'COSTA RICA', 'PHILIPPINES', 'USA TERRITORY', 'PANAMA', 'INDONESIA', 'ETHIOPIA', 'GHANA', 'NICARAGUA', 'TAIWAN', 'CANADA', 'JAMAICA', 'CUBA', 'ANTIGUA AND BARBUDA', 'ARGENTINA', 'HAITI', 'MARTINIQUE', 'MYANMAR (BURMA)', 'BANGLADESH', 'HUNGARY', 'PAPUA NEW GUINEA', 'FRENCH GUIANA', 'SAINT LUCIA', 'TOGO', 'SIERRA LEONE', 'TRINIDAD AND TOBAGO', 'CANARY ISLANDS', 'SOUTH AFRICA', 'NORWAY', 'CONGO', 'UK TERRITORY', 'GRENADA', 'GUADELOUPE', 'NEW ZEALAND', 'BARBADOS', 'SAINT VINCENT AND THE GRENADINES', 'FRENCH POLYNESIA', 'TONGA', 'SUDAN', 'AUSTRALIA', 'VANUATU', 'BRITISH VIRGIN ISLANDS', 'NEW CALEDONIA', "COTE D'IVOIRE", 'FIJI', 'SRI LANKA', 'ERITREA', 'URUGUAY', 'SOLOMON SEA', 'MONTSERRAT', 'BOLIVIA', 'SOLOMON ISLANDS', 'MONGOLIA', 'KERMADEC ISLANDS (NEW ZEALAND)', 'KIRIBATI', 'TAJIKISTAN', 'CAMEROON', 'ZAMBIA', 'MICRONESIA, FED. STATES OF', 'PALAU', 'SAMOA', 'CENTRAL AFRICAN REPUBLIC', 'ATLANTIC OCEAN', 'INDIAN OCEAN', 'SOUTH GEORGIA AND THE SOUTH SANDWICH ISLANDS', 'KENYA', 'PACIFIC OCEAN', 'UGANDA', 'BRAZIL', 'LIBYA', 'TANZANIA', 'ANTARCTICA', 'GABON', 'MALAYSIA', 'BELGIUM', 'GUINEA', 'MALAWI', 'DJIBOUTI', 'BERING SEA', 'NETHERLANDS', 'WALLIS AND FUTUNA (FRENCH TERRITORY)', 'RWANDA', 'BHUTAN', 'BURUNDI', 'SAUDI ARABIA', 'POLAND', 'VIETNAM', 'MOZAMBIQUE', 'LAOS', 'CZECH REPUBLIC', 'MADAGASCAR', 'COMOROS']

# %%
#making figure dictionary
figure = {
    'data': [],
    'layout': {},
    'frames': []
}

# %%
#Code for slider and buttons
figure['layout']['xaxis'] = {'range': [0, 180], 'title': 'Longitude'}
figure['layout']['yaxis'] = {'title': 'latitude'}
figure['layout']['hovermode'] = 'closest'
figure['layout']['sliders'] = {
    'args': [
        'transition', {
            'duration': 400,
            'easing': 'cubic-in-out'
        }
    ],
    'initialValue': '-2150',
    'plotlycommand': 'animate',
    'values': years,
    'visible': True
}
figure['layout']['updatemenus'] = [
    {
        'buttons': [
            {
                'args': [None, {'frame': {'duration': 500, 'redraw': False},
                         'fromcurrent': True, 'transition': {'duration': 300, 'easing': 'quadratic-in-out'}}],
                'label': 'Play',
                'method': 'animate'
            },
            {
                'args': [[None], {'frame': {'duration': 0, 'redraw': False}, 'mode': 'immediate',
                'transition': {'duration': 0}}],
                'label': 'Pause',
                'method': 'animate'
            }
        ],
        'direction': 'left',
        'pad': {'r': 10, 't': 87},
        'showactive': False,
        'type': 'buttons',
        'x': 0.1,
        'xanchor': 'right',
        'y': 0,
        'yanchor': 'top'
    }
]
sliders_dict = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20},
        'prefix': 'Year:',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300, 'easing': 'cubic-in-out'},
    'pad': {'b': 10, 't': 50},
    'len': 0.9,
    'x': 0.1,
    'y': 0,
    'steps': []
}

# %%
# make data
year = 1800
for country in countries:
    dataset_by_year = dataset[dataset['YEAR'] == year]
    dataset_by_year_and_cont = dataset_by_year[dataset_by_year['COUNTRY'] == country]
    data_dict = {
        'x': list(dataset_by_year_and_cont['LONGITUDE']),
        'y': list(dataset_by_year_and_cont['LATITUDE']),
        'mode': 'marker',
        'text': list(dataset_by_year_and_cont['COUNTRY']),
        'marker': {
            'sizemode': 'area',
            'sizeref': 200000,
            'size': list(dataset_by_year_and_cont['INTENSITY'])
        },
        'name': country
    }
    figure['data'].append(data_dict)

# %%
# make frames
for year in years:
    frame = {'data': [], 'name': str(year)}
    for country in countries:
        dataset_by_year = dataset[dataset['YEAR'] == int(year)]
        dataset_by_year_and_cont = dataset_by_year[dataset_by_year["COUNTRY"] == country]
        data_dict = {
            'x': list(dataset_by_year_and_cont['LONGITUDE']),
            'y': list(dataset_by_year_and_cont['LATITUDE']),
            'mode': 'marker',
            'text': list(dataset_by_year_and_cont['COUNTRY']),
            'marker': {
                'sizemode': 'area',
                'sizeref': 200000,
                'size':list(dataset_by_year_and_cont['INTENSITY'])
            },
            'name': country
        }
        frame['data'].append(data_dict)
    figure['frames'].append(frame)
    slider_step = {'args': [
        [year],
        {'frame': {'duration': 300, 'redraw': False},
         'mode': 'immediate',
       'transition': {'duration': 300}}
     ],
     'label': year,
     'method': 'animate'}
    sliders_dict['steps'].append(slider_step)
    
figure['layout']['sliders'] = [sliders_dict]
iplot(figure)
# Out:
# <div id="5b5dbaf0-4f4a-47c0-98ec-0361f31311bd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '5b5dbaf0-4f4a-47c0-98ec-0361f31311bd',
#             [{"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "JORDAN", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "TURKMENISTAN", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "SYRIA", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "GREECE", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "ISRAEL", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "ITALY", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "LEBANON", "text": [], "mode": "marker"}, {"y": ["36.2"], "marker": {"sizemode": "area", "sizeref": 200000, "size": [null]}, "x": ["53.3"], "name": "IRAN", "text": ["IRAN"], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "INDIA", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "TURKEY", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "KYRGYZSTAN", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "EGYPT", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "SPAIN", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "PORTUGAL", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "CHINA", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "RUSSIA", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "ALBANIA", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "BULGARIA", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "GEORGIA", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "CYPRUS", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "PAKISTAN", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "SOUTH KOREA", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "AFGHANISTAN", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "MACEDONIA", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "TUNISIA", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "AZERBAIJAN", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "THAILAND", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "FRANCE", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "KAZAKHSTAN", "text": [], "mode": "marker"}, {"y": [], "marker": {"sizemode": "area", "sizeref": 200000, "size": []}, "x": [], "name": "NORTH KOREA", "text": [], "mode": "marke ...
